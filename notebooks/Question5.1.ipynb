# %% [markdown]
# # Question how has inflation adjusted budget changed over time?
# We would like to know how the median inflation adjusted budget of a film has changed over time.

# %% [markdown]
# ## Load the data
# Below we import the necessary libraries and connect to the database.

# %%
import pandas as pd
import numpy as np
import cpi
import seaborn as sns
import matplotlib.pyplot as plt
from moviesdb import moviesdb as mdb

# %% [markdown]
# ### Update the consumer price index library

# %%
#cpi.update()

# %% [markdown]
# ### Connect to the database

# %%
db = mdb.MoviesDb()

# %%
query = """
SELECT start_year, production_budget
FROM budgets
"""
df = db.load_query_as_df(query)

# %% [markdown]
# ## Question specific data cleaning
# To ensure that consumer price index data is available, we restrict our analysis to movies released before 2019.

# %%
df = df.query('start_year <= 2018')

# %% [markdown]
# ## Computations
# Below we compute the median production budget aggregated by release year.

# %%
df_agg = df.groupby(by='start_year').agg('median').reset_index()

# %% [markdown]
# Next we inflate the median production budget to 2018 United States Dollars.

# %%
def inflate_to_2018(x):
    inflated = cpi.inflate(value=x[1], year_or_month=int(x[0]), to=2018)
    return inflated

# %%
df_adjusted = pd.DataFrame()
df_adjusted['start_year'] = df_agg['start_year']
df_adjusted['median_budget'] = df_agg.apply(inflate_to_2018, axis=1)

# %% [markdown]
# ## Data visualization
# Below we produce a regression plot of the median inflation adjusted production budget in 2018 USD.

# %%
fig = plt.figure(figsize=(12,8))
sns.set_context('talk')
sns.set_style('darkgrid')
ax = sns.regplot(x='start_year', y='median_budget', data=df_adjusted)
ax.set(xlabel = 'Year', 
       ylabel = 'Median Production Budget',
       title = 'Median Production Budget by Year'
      )
# Out:
# [Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Median Production Budget'),
#  Text(0.5, 1.0, 'Median Production Budget by Year')]

# %% [markdown]
# ## Conclusion
# From the plot above we conclude that there has been modest growth in the median inflation adjusted production budget from 25 million to 30 million (2018 USD).
